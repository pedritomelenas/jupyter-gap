# %%
Read("jupyter.g")

# %%
Print(ScatteredPlotTikZ([[1,1],[2,1],[1,3]]))
# Out:
# \begin{axis}[grid=both, xtick={1, 2}, ytick={1, 2}]
# \addplot [only marks] coordinates {
# (1,1)
# (2,1)
# (1,3)
# };
# \end{axis}

# %%
LoadPackage("numer")
# Out:
# #I  Please load package NormalizInterface or 4ti2Interface
# #I  to have extended functionalities.
# #I  Please load package SingularInterface or singular (not both)
# #I  or GradedModules to have extended functionalities.
# true

# %%
a:=AffineSemigroup([[2,1],[1,3],[2,2]]);
# Out:
# <Affine semigroup in 2 dimensional space, with 3 generators>

# %%
c:=Cartesian([1..10],[1..10]);;

# %%
JupyterTikZSplash(ScatteredPlotTikZ(Intersection(a,c)))
# Out:
# Success
